# %% [markdown]
# Algunos de los conceptos del calculo avanzado que se pudieron identificar en los gradientes conjugados son por ejemplo el hecho de que se tienen que construir una base de vectores ortogonales y utilizarla para buscar la solucion.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import itertools
A = np.matrix([[3.0, 2.0], [2.0, 6.0]])
b = np.matrix([[2.0], [-8.0]])  # we will use the convention that a vector is a column vector
c = 0.0
steps = [(-2.0, -2.0)]

# %%
def f(x, A, b, c):
    return float(0.5 * x.T * A * x - b.T * x + c)

# %% [markdown]
# Su forma cuadratica:
# $$f(x) = \frac{1}{2}x^\text{T}Ax-b^\text{T}x+c$$
# $$f'(x) = Ax - b$$
# $$Ax - b = 0$$

# %%
def bowl(A, b, c):
    fig = plt.figure(figsize=(10,8))
    qf = fig.gca(projection='3d')
    size = 20
    x1 = list(np.linspace(-6, 6, size))
    x2 = list(np.linspace(-6, 6, size))
    x1, x2 = np.meshgrid(x1, x2)
    zs = np.zeros((size, size))
    for i in range(size):
        for j in range(size):
            x = np.matrix([[x1[i,j]], [x2[i,j]]])
            zs[i,j] = f(x, A, b, c)
    qf.plot_surface(x1, x2, zs, rstride=1, cstride=1, linewidth=0)
    fig.show()
    return x1, x2, zs

# %%
x1, x2, zs = bowl(A, b, c)
# Out:
# <ipython-input-5-f940c23b2845>:14: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## ¿Que se podrá comprender?

# %% [markdown]
# Si es que tendriamos que ser objetivos dentro de lo leido en esta actividad lo mas factible de el calculo avanzado para comprender mas rapido y asi a la vez poder realizarlo sin tanta dificultad seria la gradiente congujado ya que en ella se puede ver materias ya vistas en ramos anteriores como funciones cuadraticas, vectores y matrices, al igual que en la manera de graficar mediante su formula conjugada.

# %% [markdown]
# ## ¿Que no se podrá comprender?

# %% [markdown]
# En si al ser un ramo profundamente importante para el desarollo de los calculos en si y por lo tanto conlleva el ser un buen profesional, hay bastantes cosas en la materia que no se puede asimilar tan facil sin que haya un guia  en el , en si estudirar de forma autonoma es un proceso personal de cada estudiante, tambien es importante que nos ayuden a crecer en conocimiento , por lo cual una simple reflexion es no hay limite de comprension pero si de tiempo

# %% [markdown]
# ## ¿Cuales son los aspectos identificables para la profundización?

# %% [markdown]
# Con el poco tiempo teniendo el ramo y con las engorrosas y "poco amigables" explicaciones que existen del tema, vemos necesario el profundizar bien estos temas

# %% [markdown]
# ##  ¿Cuales con temas de interés eventualmente relacionados?

# %% [markdown]
# Aprender especificamente que son?/cuales son? los conceptos del calculo avanzado y tanto estos conceptos como los propios gradiantes se unifican con los temas tratados en los anteriores cursos de calculo
